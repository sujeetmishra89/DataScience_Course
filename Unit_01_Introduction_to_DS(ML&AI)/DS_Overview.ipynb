# %% [markdown]
# # Core Skills

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DSLC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DIKW Pyramid

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Analytics Phases

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Types of Machine Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Artificial Intelligence

# %% [markdown]
# ![image.png](attachment:image.png)
