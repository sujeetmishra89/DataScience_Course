# %% [markdown]
# # Task Summary
# Follwing is the EDA for a public hosted database for college soccer in US.
# https://www.kaggle.com/jeffgallini/college-football-team-stats-2019/data#
#
# I have tried to find correlations within the training dataset, most influential features for winning the game.
# We have done some statistical analysis as well as augmented them with plots and visualized them.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CFB2019.csv')

# %%
df #Initial structure of the data
# Out:
#                            Team  Games Win-Loss  Off Rank  Off Plays  \
# 0     Air Force (Mountain West)     13     11-2        51        881
# 1                   Akron (MAC)     12     0-12       130        725
# 2                 Alabama (SEC)     13     11-2         6        842
# 3    Appalachian St. (Sun Belt)     14     13-1        39        969
# 4              Arizona (Pac-12)     12      4-8        30        873
# ..                          ...    ...      ...       ...        ...
# 125      West Virginia (Big 12)     12      5-7       119        788
# 126         Western Ky. (C-USA)     13      9-4        84        900
# 127         Western Mich. (MAC)     13      7-6        25        916
# 128         Wisconsin (Big Ten)     14     10-4        38        963
# 129     Wyoming (Mountain West)     13      8-5       106        831
#
#      Off Yards  Off Yards/Play  Off TDs  Off Yards per Game  Def Rank  ...  \
# 0         5483            6.22       55               421.8        17  ...
# 1         2918            4.02       14               243.2        83  ...
# 2         6640            7.89       76               510.8        20  ...
# 3         6064            6.26       65               433.1        26  ...
# 4         5281            6.05       42               440.1       120  ...
# ..         ...             ...      ...                 ...       ...  ...
# 125       3863            4.90       28               321.9        74  ...
# 126       5041            5.60       38               387.8        24  ...
# 127       5794            6.33       56               445.7        87  ...
# 128       6065            6.30       56               433.2         4  ...
# 129       4562            5.49       38               350.9        43  ...
#
#      Average Time of Possession per Game  Turnover Rank  Fumbles Recovered  \
# 0                                  34:28             78                  9
# 1                                  26:29            128                  6
# 2                                  29:59              3                 11
# 3                                  31:19              7                 10
# 4                                  27:24             89                  4
# ..                                   ...            ...                ...
# 125                                28:21            103                  6
# 126                                32:00            100                  4
# 127                                30:21             19                  9
# 128                                35:37             61                 10
# 129                                30:35             33                  8
#
#      Opponents Intercepted  Turnovers Gain  Fumbles Lost  \
# 0                        7              16            12
# 1                        5              11            12
# 2                       17              28             4
# 3                       14              24             3
# 4                       11              15             6
# ..                     ...             ...           ...
# 125                      8              14             5
# 126                     11              15             9
# 127                     13              22             6
# 128                     12              22            17
# 129                     12              20             6
#
#      Interceptions Thrown.y  Turnovers Lost  Turnover Margin  \
# 0                         6              18               -2
# 1                        14              26              -15
# 2                         6              10               18
# 3                         6               9               15
# 4                        12              18               -3
# ..                      ...             ...              ...
# 125                      15              20               -6
# 126                      12              21               -6
# 127                       8              14                8
# 128                       5              22                0
# 129                       9              15                5
#
#      Avg Turnover Margin per Game
# 0                           -0.15
# 1                           -1.25
# 2                            1.38
# 3                            1.07
# 4                           -0.25
# ..                            ...
# 125                         -0.50
# 126                         -0.46
# 127                          0.62
# 128                          0.00
# 129                          0.38
#
# [130 rows x 146 columns]

# %% [markdown]
# ##### we want to have win-loss column to be segregated in win and loss columns respectively.

# %%
new = df["Win-Loss"].str.split("-", n = 1, expand = True) #Preparing data for analysis

# %%
df["Win"]= new[0]

# %%
df["Loss"]= new[1]

# %%
df.drop(columns =["Win-Loss"], inplace = True)

# %%
# describing stats of variables
df.describe().T
# Out:
#                               count         mean         std      min  \
# Games                         130.0    12.784615    0.757235    12.00
# Off Rank                      130.0    65.492308   37.675326     1.00
# Off Plays                     130.0   885.953846   76.366300   717.00
# Off Yards                     130.0  5167.538462  953.227688  2918.00
# Off Yards/Play                130.0     5.801385    0.723159     4.02
# ...                             ...          ...         ...      ...
# Fumbles Lost                  130.0     8.200000    2.963342     2.00
# Interceptions Thrown.y        130.0     9.976923    3.652472     1.00
# Turnovers Lost                130.0    18.176923    4.584208     6.00
# Turnover Margin               130.0     0.323077    7.545434   -15.00
# Avg Turnover Margin per Game  130.0     0.012385    0.586483    -1.25
#
#                                     25%       50%      75%      max
# Games                           12.0000    13.000    13.00    15.00
# Off Rank                        33.2500    65.500    97.75   130.00
# Off Plays                      841.0000   881.000   936.50  1080.00
# Off Yards                     4580.2500  5123.500  5712.75  8527.00
# Off Yards/Play                   5.3125     5.815     6.22     7.96
# ...                                 ...       ...      ...      ...
# Fumbles Lost                     6.0000     8.000    10.00    17.00
# Interceptions Thrown.y           8.0000    10.000    12.00    20.00
# Turnovers Lost                  15.0000    18.000    21.00    30.00
# Turnover Margin                 -5.0000     0.000     5.00    21.00
# Avg Turnover Margin per Game    -0.4200     0.000     0.38     1.50
#
# [142 rows x 8 columns]

# %%
df.shape  #this represents shape of the df 130 rows and 147 columns.
# Out:
# (130, 147)

# %%
df.columns # column names
# Out:
# Index(['Team', 'Games', 'Off Rank', 'Off Plays', 'Off Yards', 'Off Yards/Play',
#        'Off TDs', 'Off Yards per Game', 'Def Rank', 'Def Plays',
#        ...
#        'Fumbles Recovered', 'Opponents Intercepted', 'Turnovers Gain',
#        'Fumbles Lost', 'Interceptions Thrown.y', 'Turnovers Lost',
#        'Turnover Margin', 'Avg Turnover Margin per Game', 'Win', 'Loss'],
#       dtype='object', length=147)

# %%
df.info
# Out:
# <bound method DataFrame.info of                            Team  Games  Off Rank  Off Plays  Off Yards  \
# 0     Air Force (Mountain West)     13        51        881       5483
# 1                   Akron (MAC)     12       130        725       2918
# 2                 Alabama (SEC)     13         6        842       6640
# 3    Appalachian St. (Sun Belt)     14        39        969       6064
# 4              Arizona (Pac-12)     12        30        873       5281
# ..                          ...    ...       ...        ...        ...
# 125      West Virginia (Big 12)     12       119        788       3863
# 126         Western Ky. (C-USA)     13        84        900       5041
# 127         Western Mich. (MAC)     13        25        916       5794
# 128         Wisconsin (Big Ten)     14        38        963       6065
# 129     Wyoming (Mountain West)     13       106        831       4562
#
#      Off Yards/Play  Off TDs  Off Yards per Game  Def Rank  Def Plays  ...  \
# 0              6.22       55               421.8        17        752  ...
# 1              4.02       14               243.2        83        871  ...
# 2              7.89       76               510.8        20        877  ...
# 3              6.26       65               433.1        26        940  ...
# 4              6.05       42               440.1       120        889  ...
# ..              ...      ...                 ...       ...        ...  ...
# 125            4.90       28               321.9        74        874  ...
# 126            5.60       38               387.8        24        835  ...
# 127            6.33       56               445.7        87        932  ...
# 128            6.30       56               433.2         4        839  ...
# 129            5.49       38               350.9        43        941  ...
#
#      Fumbles Recovered  Opponents Intercepted  Turnovers Gain  Fumbles Lost  \
# 0                    9                      7              16            12
# 1                    6                      5              11            12
# 2                   11                     17              28             4
# 3                   10                     14              24             3
# 4                    4                     11              15             6
# ..                 ...                    ...             ...           ...
# 125                  6                      8              14             5
# 126                  4                     11              15             9
# 127                  9                     13              22             6
# 128                 10                     12              22            17
# 129                  8                     12              20             6
#
#      Interceptions Thrown.y  Turnovers Lost  Turnover Margin  \
# 0                         6              18               -2
# 1                        14              26              -15
# 2                         6              10               18
# 3                         6               9               15
# 4                        12              18               -3
# ..                      ...             ...              ...
# 125                      15              20               -6
# 126                      12              21               -6
# 127                       8              14                8
# 128                       5              22                0
# 129                       9              15                5
#
#      Avg Turnover Margin per Game  Win  Loss
# 0                           -0.15   11     2
# 1                           -1.25    0    12
# 2                            1.38   11     2
# 3                            1.07   13     1
# 4                           -0.25    4     8
# ..                            ...  ...   ...
# 125                         -0.50    5     7
# 126                         -0.46    9     4
# 127                          0.62    7     6
# 128                          0.00   10     4
# 129                          0.38    8     5
#
# [130 rows x 147 columns]>

# %%
df.dtypes
team = df['Team']

# %%
df[['Win']] = df[['Win']].apply(pd.to_numeric, errors='coerce')

# %%
cor = df.corr()

# %%
#Correlation with respect to Win variable and filtering out variables with less correlation.
columns = cor[cor["Win"]>0.75]['Win']
columns_list = columns.index
columns_list
# Out:
# Index(['Games', 'Off Yards', 'Off TDs', 'First Downs', 'Redzone Scores',
#        'Touchdowns', 'PAT', 'Total Points', 'Points Per Game', 'Win'],
#       dtype='object')

# %%
df1 = pd.DataFrame(df, columns=columns_list)

# %%
df2 = df1.drop('Games', axis= 1)
df2['Team'] = team

# %%
#create the correlation matrix heat map
plt.figure(figsize=(14,12))

sns.heatmap(df2.corr(),linewidths=.1,cmap="YlGnBu", annot=True)

plt.yticks(rotation=0);

# %%
#pair plots
g = sns.pairplot(df2)

# %%
# Plot colored by continent for years 2000-2007
sns.pairplot(df2[df2['Win'] > 5], 
             vars = ['Off Yards', 'Touchdowns', 'PAT'], diag_kind = 'kde', 
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
             size = 4);
# Title 
plt.suptitle('Pair Plot of influential factors for winning', 
             size = 28);
# Out:
# C:\Users\PR269KB\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
